# %%
from graphics import *
import random as rd
import time

'''WIN & MATTHEW'''
win = GraphWin("Battle Ships", 1150, 600) #creates a window with “BattleShips” in top right corner
win.setBackground("white") #this makes a white background for the game window

def GridLine(a,b,c,d): #function that draws lines when given 2 points
    line = Line(Point(a,b), Point(c,d))
    return line

def Player_Grid(): #function that draw the board of player
    for i in range(0,11): # 0 - 10 on the board
        hline = GridLine(0,i*50,500,i*50) #horizontal lines of the player grid
        hline.draw(win) #draws the lines in the window
        vline = GridLine(i*50,0,i*50,500) #vertical lines of the player grid
        vline.draw(win) #draws the lines in the window

def Computer_Gird(): #function that draw the board of computer
    for i in range(0,11): # 0 - 10 on the board
        hline = GridLine(600,i*50,1100,i*50) #horizontal lines of the computer grid
        hline.draw(win) #draws the lines on the window
        vline = GridLine(i*50+600,0,i*50+600,500) #vertical lines of the computer grid
        vline.draw(win) #draws the lines on the window

def X_axis(): #function that draw the X-axis for two board
    X_axis = "ABCDEFGHIK" #the letters on the bottom of the x-axis
    XPoint_player = 515 #where the letters will be in terms of pixels
    XPoint_computer = 1115 #where computer’s letters will be in terms of pixels
    YPoint = 25
    for i in X_axis:
        XaxisPlayer = Text(Point(XPoint_player, YPoint), i)
        XaxisComputer = Text(Point(XPoint_computer, YPoint), i)
        YPoint += 50
        XaxisPlayer.draw(win)
        XaxisComputer.draw(win)

def Y_axis(): #function that draw the Y-axis for two board
    Y_axis = "0123456789" #the numbers throughout the y-axis
    YPoint = 515
    XPoint = 25
    for i in Y_axis:
        YaxisPlayer = Text(Point(XPoint, YPoint), i)
        YaxisComputer = Text(Point(XPoint + 600, YPoint), i)
        XPoint += 50
        YaxisPlayer.draw(win)
        YaxisComputer.draw(win)

def Player_Name(): #function that write player name
    Player_Name = str(input("Enter your name, Captain!"))
    YPoint = 550
    XPoint = 25
    for i in Player_Name:
        YaxisPlayer = Text(Point(XPoint, YPoint), i)
        XPoint += 10
        YaxisPlayer.draw(win)

def Computer_Name(): #function that write computer name 
    Computer_Name = str(input("Enter your enemy's name, Captain!"))
    YPoint = 550
    XPoint = 625
    for i in Computer_Name:
        YaxisPlayer = Text(Point(XPoint, YPoint), i)
        XPoint += 10
        YaxisPlayer.draw(win)

def MousePosition(): #function that take coordination of the mouse
    Mouse = Point(1, 1)
    Mouse = win.getMouse()
    X = Mouse.getX()
    Y = Mouse.getY()
    return X,Y

'''WIN, MATTHEW...PLAYER PART BEGIN'''
def Coodination_Player(X,Y): # coordinates selected by computer to try to hit player ships
    cood_X = X
    cood_Y = Y
    if 0<= X <=50:
        cood_X = "0"
    elif X <= 100:
        cood_X = "1"
    elif X <= 150:
        cood_X = "2"
    elif X <= 200:
        cood_X = "3"
    elif X <= 250:
        cood_X = "4"
    elif X <= 300:
        cood_X = "5"
    elif X <= 350:
        cood_X = "6"
    elif X <= 400:
        cood_X = "7"
    elif X <= 450:
        cood_X = "8"
    elif X <= 500:
        cood_X = "9"
        
    if 0<= Y <=50:
        cood_Y = "A"
    elif Y <= 100:
        cood_Y = "B"
    elif Y <= 150:
        cood_Y = "C"
    elif Y <= 200:
        cood_Y = "D"
    elif Y <= 250:
        cood_Y = "E"
    elif Y <= 300:
        cood_Y = "F"
    elif Y <= 350:
        cood_Y = "G"
    elif Y <= 400:
        cood_Y = "H"
    elif Y <= 450:
        cood_Y = "I"
    elif Y <= 500:
        cood_Y = "K"
    return cood_Y + cood_X 

def DrawPlayer(position, color): # records color of hit or miss on player’s board
    color = color
    #A column
    if position == "A0":
        Draw = Rectangle(Point(1, 1), Point(49, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A1":
        Draw = Rectangle(Point(51, 1), Point(99, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A2":
        Draw = Rectangle(Point(101, 1), Point(149, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A3":
        Draw = Rectangle(Point(151, 1), Point(199, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A4":
        Draw = Rectangle(Point(201, 1), Point(249, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A5":
        Draw = Rectangle(Point(251, 1), Point(299, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A6":
        Draw = Rectangle(Point(301, 1), Point(349 ,49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A7":
        Draw = Rectangle(Point(351, 1), Point(399, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A8":
        Draw = Rectangle(Point(401, 1), Point(449, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A9":
        Draw = Rectangle(Point(451, 1), Point(499, 49))
        Draw.setFill(color)
        Draw.draw(win)
    
    #B column
    elif position == "B0":
        Draw = Rectangle(Point(1, 51), Point(49, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B1":
        Draw = Rectangle(Point(51, 51), Point(99, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B2":
        Draw = Rectangle(Point(101, 51), Point(149, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B3":
        Draw = Rectangle(Point(151, 51), Point(199, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B4":
        Draw = Rectangle(Point(201, 51), Point(249, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B5":
        Draw = Rectangle(Point(251, 51), Point(299, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B6":
        Draw = Rectangle(Point(301, 51), Point(349 ,99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B7":
        Draw = Rectangle(Point(351, 51), Point(399, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B8":
        Draw = Rectangle(Point(401, 51), Point(449, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B9":
        Draw = Rectangle(Point(451, 51), Point(499, 99))
        Draw.setFill(color)
        Draw.draw(win)    
    
    #C column
    elif position == "C0":
        Draw = Rectangle(Point(1, 101), Point(49, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C1":
        Draw = Rectangle(Point(51, 101), Point(99, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C2":
        Draw = Rectangle(Point(101, 101), Point(149, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C3":
        Draw = Rectangle(Point(151, 101), Point(199, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C4":
        Draw = Rectangle(Point(201, 101), Point(249, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C5":
        Draw = Rectangle(Point(251, 101), Point(299, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C6":
        Draw = Rectangle(Point(301, 101), Point(349 ,149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C7":
        Draw = Rectangle(Point(351, 101), Point(399, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C8":
        Draw = Rectangle(Point(401, 101), Point(449, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C9":
        Draw = Rectangle(Point(451, 101), Point(499, 149))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #D Column
    elif position == "D0":
        Draw = Rectangle(Point(1, 151), Point(49, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D1":
        Draw = Rectangle(Point(51, 151), Point(99, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D2":
        Draw = Rectangle(Point(101, 151), Point(149, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D3":
        Draw = Rectangle(Point(151, 151), Point(199, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D4":
        Draw = Rectangle(Point(201, 151), Point(249, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D5":
        Draw = Rectangle(Point(251, 151), Point(299, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D6":
        Draw = Rectangle(Point(301, 151), Point(349 ,199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D7":
        Draw = Rectangle(Point(351, 151), Point(399, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D8":
        Draw = Rectangle(Point(401, 151), Point(449, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D9":
        Draw = Rectangle(Point(451, 151), Point(499, 199))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #E Column
    elif position == "E0":
        Draw = Rectangle(Point(1, 201), Point(49, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E1":
        Draw = Rectangle(Point(51, 201), Point(99, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E2":
        Draw = Rectangle(Point(101, 201), Point(149, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E3":
        Draw = Rectangle(Point(151, 201), Point(199, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E4":
        Draw = Rectangle(Point(201, 201), Point(249, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E5":
        Draw = Rectangle(Point(251, 201), Point(299, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E6":
        Draw = Rectangle(Point(301, 201), Point(349 ,249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E7":
        Draw = Rectangle(Point(351, 201), Point(399, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E8":
        Draw = Rectangle(Point(401, 201), Point(449, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E9":
        Draw = Rectangle(Point(451, 201), Point(499, 249))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #F Column
    elif position == "F0":
        Draw = Rectangle(Point(1, 251), Point(49, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F1":
        Draw = Rectangle(Point(51, 251), Point(99, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F2":
        Draw = Rectangle(Point(101, 251), Point(149, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F3":
        Draw = Rectangle(Point(151, 251), Point(199, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F4":
        Draw = Rectangle(Point(201, 251), Point(249, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F5":
        Draw = Rectangle(Point(251, 251), Point(299, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F6":
        Draw = Rectangle(Point(301, 251), Point(349 ,299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F7":
        Draw = Rectangle(Point(351, 251), Point(399, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F8":
        Draw = Rectangle(Point(401, 251), Point(449, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F9":
        Draw = Rectangle(Point(451, 251), Point(499, 299))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #G Column
    elif position == "G0":
        Draw = Rectangle(Point(1, 301), Point(49, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G1":
        Draw = Rectangle(Point(51, 301), Point(99, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G2":
        Draw = Rectangle(Point(101, 301), Point(149, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G3":
        Draw = Rectangle(Point(151, 301), Point(199, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G4":
        Draw = Rectangle(Point(201, 301), Point(249, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G5":
        Draw = Rectangle(Point(251, 301), Point(299, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G6":
        Draw = Rectangle(Point(301, 301), Point(349 ,349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G7":
        Draw = Rectangle(Point(351, 301), Point(399, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G8":
        Draw = Rectangle(Point(401, 301), Point(449, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G9":
        Draw = Rectangle(Point(451, 301), Point(499, 349))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #H Column
    elif position == "H0":
        Draw = Rectangle(Point(1, 351), Point(49, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H1":
        Draw = Rectangle(Point(51, 351), Point(99, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H2":
        Draw = Rectangle(Point(101, 351), Point(149, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H3":
        Draw = Rectangle(Point(151, 351), Point(199, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H4":
        Draw = Rectangle(Point(201, 351), Point(249, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H5":
        Draw = Rectangle(Point(251, 351), Point(299, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H6":
        Draw = Rectangle(Point(301, 351), Point(349 ,399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H7":
        Draw = Rectangle(Point(351, 351), Point(399, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H8":
        Draw = Rectangle(Point(401, 351), Point(449, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H9":
        Draw = Rectangle(Point(451, 351), Point(499, 399))
        Draw.setFill(color)
        Draw.draw(win)
        
    #I Column
    elif position == "I0":
        Draw = Rectangle(Point(1, 401), Point(49, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I1":
        Draw = Rectangle(Point(51, 401), Point(99, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I2":
        Draw = Rectangle(Point(101, 401), Point(149, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I3":
        Draw = Rectangle(Point(151, 401), Point(199, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I4":
        Draw = Rectangle(Point(201, 401), Point(249, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I5":
        Draw = Rectangle(Point(251, 401), Point(299, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I6":
        Draw = Rectangle(Point(301, 401), Point(349 , 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I7":
        Draw = Rectangle(Point(351, 401), Point(399, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I8":
        Draw = Rectangle(Point(401, 401), Point(449, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I9":
        Draw = Rectangle(Point(451, 401), Point(499, 449))
        Draw.setFill(color)
        Draw.draw(win)
        
    #K Column
    elif position == "K0":
        Draw = Rectangle(Point(1, 451), Point(49, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K1":
        Draw = Rectangle(Point(51, 451), Point(99, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K2":
        Draw = Rectangle(Point(101, 451), Point(149, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K3":
        Draw = Rectangle(Point(151, 451), Point(199, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K4":
        Draw = Rectangle(Point(201, 451), Point(249, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K5":
        Draw = Rectangle(Point(251, 451), Point(299, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K6":
        Draw = Rectangle(Point(301, 451), Point(349 , 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K7":
        Draw = Rectangle(Point(351, 451), Point(399, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K8":
        Draw = Rectangle(Point(401, 451), Point(449, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K9":
        Draw = Rectangle(Point(451, 451), Point(499, 499))
        Draw.setFill(color)
        Draw.draw(win) 

'''HADEN & WIN'''    
def SEEKFILE(afile,C):
    "This function seeks the ship in file"
    P_BShip_list = []
    file = open(afile, "r")
    BShip = file.read()
    BShip_list = BShip.split("\n")
    for i in range(len(BShip_list)):
        if BShip_list[i].startswith(C) or BShip_list[i].endswith(C):
                P_BShip_list.append(BShip_list[i])
    file.close()
    return P_BShip_list 
        
def ShipList_PLAYER(): 
    ShipList = []
    count = 0
    print("Place your Ships")
    
    while True:
        if len(ShipList) == 10:
            break
        
        erase = True
        M_X,M_Y = MousePosition()
        C1 = Coodination_Player(M_X,M_Y)
        if C1 in ShipList:
            print("You have chosen this position, try again")
            continue
        shipcolor = "green"
        DrawPlayer(C1, shipcolor)
        
        if len(ShipList) == 0 or len(ShipList) == 4:
            P_BShip_list = SEEKFILE("SHIP_FOUR.txt",C1)
            print("Place a 4x1 Ship")
        elif len(ShipList) == 8:
            P_BShip_list = SEEKFILE("SHIP_TWO.txt",C1)
            print("Place a 2x1 Ship")
        
        M_X,M_Y = MousePosition()
        C2 = Coodination_Player(M_X,M_Y)
        for i in range(len(P_BShip_list)):
            if P_BShip_list[i].startswith(C2) or P_BShip_list[i].endswith(C2):
                erase = False
                for j in range(0,len(P_BShip_list[i]),2):
                    shipcolor = "green"
                    DrawPlayer(P_BShip_list[i][j:j+2], shipcolor)
                    ShipList.append(P_BShip_list[i][j:j+2])
                    
            if erase:
                
                DrawPlayer(C1, "white")
                
                          
    return ShipList

'''MARK, WIN, BRIAN'''
def HITorMISS_COM(ShipList, All, MarkList_Computer):
    while True:					# while hits are selected computer proceeds with block below
        M_X = rd.randint(0,500)			# select random x integer, 0-500
        M_Y = rd.randint(0,500)			# select random y integer, 0-500
        C_COM = Coodination_Player(M_X,M_Y) # converts computer selected coords to 0-9 and A-K
        status = False				# status is used to continue turn if there is a hit
        if C_COM not in MarkList_Computer:	# checks that computer coords are not in list of chosen coords
            for i in range(len(ShipList)):		# check if computer selected coords are in the player’s ship list
                if C_COM == ShipList[i]:		# if computer selected coords match an instance of player’s ships 
                    print("Computer HIT")
                    hitcolor = "red"
                    DrawPlayer(C_COM, hitcolor)		# records color of a hit to the player board
                    MarkList_Computer.append(C_COM) # add coord to list of chosen coords, cannot be used again 
                    status = True				# status changed to true to allow computer to go again
                    All += 1					# record hits
                    CONTINUE = "COMPUTER"		# command for computer to continue its turn
                    time.sleep(1.5)				# suspend execution for 1.5 seconds
                    break
            if status == False:				# if computer coord did not match, there is a miss
                print("Computer MISS")			# status becomes false, MarkList updated
                misscolor = "blue"				
                DrawPlayer(C_COM, misscolor)		# records color of a miss to the player board
                MarkList_Computer.append(C_COM)	# coord cannot be used again
                CONTINUE = "PLAYER"			# becomes player’s turn since computer missed
        else:
            continue
            
        if All == len(ShipList):			# if hits equals length of player’s ShipList, Computer wins
            print("Computer win")
            break
        else:
            return CONTINUE, All 
'''PLAYER PART END'''            
    
'''WIN, MATTHEW...COMPUTER PART BEGIN'''
def Coodination_COM(X,Y): # Coordinates selected by player to try to hit computer ships
    cood_X = X
    cood_Y = Y
    if 600<= X <=650:
        cood_X = "0"
    elif X <= 700:
        cood_X = "1"
    elif X <= 750:
        cood_X = "2"
    elif X <= 800:
        cood_X = "3"
    elif X <= 850:
        cood_X = "4"
    elif X <= 900:
        cood_X = "5"
    elif X <= 950:
        cood_X = "6"
    elif X <= 1000:
        cood_X = "7"
    elif X <= 1050:
        cood_X = "8"
    elif X <= 1100:
        cood_X = "9"
        
    if 0<= Y <=50:
        cood_Y = "A"
    elif Y <= 100:
        cood_Y = "B"
    elif Y <= 150:
        cood_Y = "C"
    elif Y <= 200:
        cood_Y = "D"
    elif Y <= 250:
        cood_Y = "E"
    elif Y <= 300:
        cood_Y = "F"
    elif Y <= 350:
        cood_Y = "G"
    elif Y <= 400:
        cood_Y = "H"
    elif Y <= 450:
        cood_Y = "I"
    elif Y <= 500:
        cood_Y = "K"
    return cood_Y + cood_X 

def DrawCom(position, color): # records color of hit or miss on computer board
    color = color
    #A column
    if position == "A0":
        Draw = Rectangle(Point(601, 1), Point(649, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A1":
        Draw = Rectangle(Point(651, 1), Point(699, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A2":
        Draw = Rectangle(Point(701, 1), Point(749, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A3":
        Draw = Rectangle(Point(751, 1), Point(799, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A4":
        Draw = Rectangle(Point(801, 1), Point(849, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A5":
        Draw = Rectangle(Point(851, 1), Point(899, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A6":
        Draw = Rectangle(Point(901, 1), Point(949 ,49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A7":
        Draw = Rectangle(Point(951, 1), Point(999, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A8":
        Draw = Rectangle(Point(1001, 1), Point(1049, 49))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "A9":
        Draw = Rectangle(Point(1051, 1), Point(1099, 49))
        Draw.setFill(color)
        Draw.draw(win)
    
    #B column
    elif position == "B0":
        Draw = Rectangle(Point(601, 51), Point(649, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B1":
        Draw = Rectangle(Point(651, 51), Point(699, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B2":
        Draw = Rectangle(Point(701, 51), Point(749, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B3":
        Draw = Rectangle(Point(751, 51), Point(799, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B4":
        Draw = Rectangle(Point(801, 51), Point(849, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B5":
        Draw = Rectangle(Point(851, 51), Point(899, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B6":
        Draw = Rectangle(Point(901, 51), Point(949, 99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B7":
        Draw = Rectangle(Point(951, 51), Point(999,  99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B8":
        Draw = Rectangle(Point(1001, 51), Point(1049,  99))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "B9":
        Draw = Rectangle(Point(1051, 51), Point(1099, 99))
        Draw.setFill(color)
        Draw.draw(win)    
    
    #C column
    elif position == "C0":
        Draw = Rectangle(Point(601, 101), Point(649, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C1":
        Draw = Rectangle(Point(651, 101), Point(699, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C2":
        Draw = Rectangle(Point(701, 101), Point(749, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C3":
        Draw = Rectangle(Point(751, 101), Point(799, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C4":
        Draw = Rectangle(Point(801, 101), Point(849, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C5":
        Draw = Rectangle(Point(851, 101), Point(899, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C6":
        Draw = Rectangle(Point(901, 101), Point(949, 149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C7":
        Draw = Rectangle(Point(951, 101), Point(999,  149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C8":
        Draw = Rectangle(Point(1001, 101), Point(1049,  149))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "C9":
        Draw = Rectangle(Point(1051, 101), Point(1099, 149))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #D Column
    elif position == "D0":
        Draw = Rectangle(Point(601, 151), Point(649, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D1":
        Draw = Rectangle(Point(651, 151), Point(699, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D2":
        Draw = Rectangle(Point(701, 151), Point(749, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D3":
        Draw = Rectangle(Point(751, 151), Point(799, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D4":
        Draw = Rectangle(Point(801, 151), Point(849, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D5":
        Draw = Rectangle(Point(851, 151), Point(899, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D6":
        Draw = Rectangle(Point(901, 151), Point(949, 199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D7":
        Draw = Rectangle(Point(951, 151), Point(999,  199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D8":
        Draw = Rectangle(Point(1001, 151), Point(1049,  199))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "D9":
        Draw = Rectangle(Point(1051, 151), Point(1099, 199))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #E Column
    elif position == "E0":
        Draw = Rectangle(Point(601, 201), Point(649, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E1":
        Draw = Rectangle(Point(651, 201), Point(699, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E2":
        Draw = Rectangle(Point(701, 201), Point(749, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E3":
        Draw = Rectangle(Point(751, 201), Point(799, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E4":
        Draw = Rectangle(Point(801, 201), Point(849, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E5":
        Draw = Rectangle(Point(851, 201), Point(899, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E6":
        Draw = Rectangle(Point(901, 201), Point(949, 249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E7":
        Draw = Rectangle(Point(951, 201), Point(999,  249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E8":
        Draw = Rectangle(Point(1001, 201), Point(1049,  249))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "E9":
        Draw = Rectangle(Point(1051, 201), Point(1099, 249))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #F Column
    elif position == "F0":
        Draw = Rectangle(Point(601, 251), Point(649, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F1":
        Draw = Rectangle(Point(651, 251), Point(699, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F2":
        Draw = Rectangle(Point(701, 251), Point(749, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F3":
        Draw = Rectangle(Point(751, 251), Point(799, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F4":
        Draw = Rectangle(Point(801, 251), Point(849, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F5":
        Draw = Rectangle(Point(851, 251), Point(899, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F6":
        Draw = Rectangle(Point(901, 251), Point(949, 299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F7":
        Draw = Rectangle(Point(951, 251), Point(999,  299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F8":
        Draw = Rectangle(Point(1001, 251), Point(1049,  299))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "F9":
        Draw = Rectangle(Point(1051, 251), Point(1099, 299))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #G Column
    elif position == "G0":
        Draw = Rectangle(Point(601, 301), Point(649, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G1":
        Draw = Rectangle(Point(651, 301), Point(699, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G2":
        Draw = Rectangle(Point(701, 301), Point(749, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G3":
        Draw = Rectangle(Point(751, 301), Point(799, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G4":
        Draw = Rectangle(Point(801, 301), Point(849, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G5":
        Draw = Rectangle(Point(851, 301), Point(899, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G6":
        Draw = Rectangle(Point(901, 301), Point(949, 349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G7":
        Draw = Rectangle(Point(951, 301), Point(999,  349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G8":
        Draw = Rectangle(Point(1001, 301), Point(1049,  349))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "G9":
        Draw = Rectangle(Point(1051, 301), Point(1099, 349))
        Draw.setFill(color)
        Draw.draw(win) 
        
    #H Column
    elif position == "H0":
        Draw = Rectangle(Point(601, 351), Point(649, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H1":
        Draw = Rectangle(Point(651, 351), Point(699, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H2":
        Draw = Rectangle(Point(701, 351), Point(749, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H3":
        Draw = Rectangle(Point(751, 351), Point(799, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H4":
        Draw = Rectangle(Point(801, 351), Point(849, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H5":
        Draw = Rectangle(Point(851, 351), Point(899, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H6":
        Draw = Rectangle(Point(901, 351), Point(949, 399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H7":
        Draw = Rectangle(Point(951, 351), Point(999,  399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H8":
        Draw = Rectangle(Point(1001, 351), Point(1049,  399))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "H9":
        Draw = Rectangle(Point(1051, 351), Point(1099, 399))
        Draw.setFill(color)
        Draw.draw(win)
        
    #I Column
    elif position == "I0":
        Draw = Rectangle(Point(601, 401), Point(649, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I1":
        Draw = Rectangle(Point(651, 401), Point(699, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I2":
        Draw = Rectangle(Point(701, 401), Point(749, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I3":
        Draw = Rectangle(Point(751, 401), Point(799, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I4":
        Draw = Rectangle(Point(801, 401), Point(849, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I5":
        Draw = Rectangle(Point(851, 401), Point(899, 449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I6":
        Draw = Rectangle(Point(901, 401), Point(949,  449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I7":
        Draw = Rectangle(Point(951, 401), Point(999,  449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I8":
        Draw = Rectangle(Point(1001, 401), Point(1049,  449))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "I9":
        Draw = Rectangle(Point(1051, 401), Point(1099, 449))
        Draw.setFill(color)
        Draw.draw(win)
        
    #K Column
    elif position == "K0":
        Draw = Rectangle(Point(601, 451), Point(649, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K1":
        Draw = Rectangle(Point(651, 451), Point(699, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K2":
        Draw = Rectangle(Point(701, 451), Point(749, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K3":
        Draw = Rectangle(Point(751, 451), Point(799, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K4":
        Draw = Rectangle(Point(801, 451), Point(849, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K5":
        Draw = Rectangle(Point(851, 451), Point(899, 499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K6":
        Draw = Rectangle(Point(901, 451), Point(949,  499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K7":
        Draw = Rectangle(Point(951, 451), Point(999,  499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K8":
        Draw = Rectangle(Point(1001, 451), Point(1049,  499))
        Draw.setFill(color)
        Draw.draw(win)
    elif position == "K9":
        Draw = Rectangle(Point(1051, 451), Point(1099, 499))
        Draw.setFill(color)
        Draw.draw(win) 

'''HADEN, BRIAN, WIN'''        
def OPENFILE(afile):
    "This function opens the ship file"
    file = open(afile, "r")
    BShip = file.read()
    BShip_list = BShip.split("\n")
    file.close()
    return BShip_list        

def ShipList_COM(BShip_Four, BShip_Two):
    New_BShip_list = []

    #Making sure that the list does not have any non-position ship
    BShip_Four.remove("")
    BShip_Two.remove("")
    
    while True:
        for i in range(2):
            getone_four = rd.choice(BShip_Four)
            for j in range(0,len(getone_four),2):
                New_BShip_list.append(getone_four[j:j+2])

        getone_two = rd.choice(BShip_Two)
        for j in range(0,len(getone_two),2):
            New_BShip_list.append(getone_two[j:j+2])

        if len(set(New_BShip_list)) == 10: # Uses set function to force unique values; prevents ship overlapping
            break
        else:
            New_BShip_list = []
            continue



    ShipList_COM = []
    count = 0
    while True:
            #M_X,M_Y = MousePosition()
            #M_X = rd.randint(600,1100)
            #M_Y = rd.randint(0,500)
            #C = Coodination_COM(M_X,M_Y)
        for C in New_BShip_list:
            if C not in ShipList_COM:
                shipcolor = "green"
                # DrawCom(C, shipcolor) # REMOVE HASHTAG before DrawCom to see Computer ships
					# LEAVE HASHTAG before DrawCom for final submitted version
                ShipList_COM.append(C)
                count += 1
            else:
                continue
        if count == 10:
            break
    print("Attack your enemy's Ships")
    return ShipList_COM

'''WIN, MARK, BRIAN'''
def HITorMISS_PLAYER(ShipList, All, MarkList_Player):
    while True:
        M_X,M_Y = MousePosition()
        C_PLAYER = Coodination_COM(M_X,M_Y)
        status = False
        if C_PLAYER not in MarkList_Player:
            for i in range(len(ShipList)):
                if C_PLAYER == ShipList[i]:
                    print("You HIT")
                    hitcolor = "red"
                    DrawCom(C_PLAYER, hitcolor)
                    MarkList_Player.append(C_PLAYER)
                    status = True
                    All += 1
                    CONTINUE = "PLAYER"
                    break
            if status == False:
                print("You MISS")
                misscolor = "blue"
                DrawCom(C_PLAYER, misscolor)
                MarkList_Player.append(C_PLAYER)
                CONTINUE = "COMPUTER"
        else:
            continue
            
        if All == len(ShipList):
            print("You win")
            break
        else:
            return CONTINUE, All           
'''COMPUTER PART END'''
    
'''WIN & MARK'''
def GameOutcome(ShipPlayer,ShipComputer):
    All1 = 0 #To know the number of computer ship get HIT
    All2 = 0 #To know the number of player ship get HIT
    Con = "PLAYER" #player go first
    MarkList_Computer = [] #To know where computer has stroke
    MarkList_Player = [] #To know where player has stroke
    try:		# Player and Computer take turn and when someone win, print the game over
        while True:
            if Con == "PLAYER":
                Con, All1 = HITorMISS_PLAYER(ShipComputer, All1, MarkList_Player)
            elif Con == "COMPUTER":
                Con, All2 = HITorMISS_COM(ShipPlayer, All2, MarkList_Computer)
    except TypeError:
        print("Game over")

'''MARK & WIN'''
def Main():
    Player_Grid()
    Computer_Gird()
    X_axis()
    Y_axis()
    #Player_Name()
    #Computer_Name()
    a = OPENFILE("SHIP_FOUR.txt")
    b = OPENFILE("SHIP_TWO.txt")
    ShipPlayer = ShipList_PLAYER()
    ShipComputer = ShipList_COM(a,b)
    GameOutcome(ShipPlayer,ShipComputer)
    win.getMouse() # Pause to view result
    win.close()    # Close window when done

Main()

#Note: Ships are green
#      hits are red
#      miss are blue
# Out:
# Place your Ships
# Place a 4x1 Ship
# Place a 4x1 Ship
# Place a 2x1 Ship
# Attack your enemy's Ships
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer HIT
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer HIT
# Computer MISS
# You HIT
# You MISS
# Computer HIT
# Computer HIT
# Computer MISS
# You HIT
# You HIT
# You HIT
# You MISS
# Computer HIT
# Computer MISS
# You MISS
# Computer MISS
# You HIT
# You HIT
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# You MISS
# Computer MISS
# ...
